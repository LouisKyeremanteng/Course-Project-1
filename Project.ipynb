# %% [markdown]
# ## Credentials
# - Name   Louis Kyeremanteng
# - ID     11298161
# - Class  MTEN

# %%
# Importing python libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("red_wine.csv")

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# Preview of first 10 rows
dataset.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6        NaN
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
# Previw of last 20 rows
dataset.tail(20)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
#Using info method to check for data info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
# Using the describe method to obtain statistical information
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %% [markdown]
# ## Pre processing data

# %% [markdown]
# ### 1. Dropping null values

# %%
dataset.dropna(inplace=True)

# %%
# New dataset info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1590 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1590 non-null   float64
#  1   volatile acidity      1590 non-null   float64
#  2   citric acid           1590 non-null   float64
#  3   residual sugar        1590 non-null   float64
#  4   chlorides             1590 non-null   float64
#  5   free sulfur dioxide   1590 non-null   float64
#  6   total sulfur dioxide  1590 non-null   float64
#  7   density               1590 non-null   float64
#  8   pH                    1590 non-null   float64
#  9   sulphates             1590 non-null   float64
#  10  alcohol               1590 non-null   float64
#  11  quality               1590 non-null   float64
# dtypes: float64(12)
# memory usage: 161.5 KB

# %%
#Checking for any overlooked correction
dataset.isnull().any().any()
# Out:
# False

# %% [markdown]
# - There is no empty data

# %% [markdown]
# ### 2. Removal of duplicates

# %%
dataset.drop_duplicates(inplace=True)

# %%
# Checking for any duplicates
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 1593    False
# 1594    False
# 1595    False
# 1597    False
# 1598    False
# Length: 1351, dtype: bool

# %% [markdown]
# - No duplicated data

# %%
dataset.shape
# Out:
# (1351, 12)

# %% [markdown]
# - After processing the data 1351 rows and 12 columns were left

# %% [markdown]
# ## Obtaining description of data for each clomun

# %%
# For fixed acidity
dataset["fixed acidity"].describe()
# Out:
# count    1598.000000
# mean        8.318335
# std         1.740863
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed acidity, dtype: float64

# %%
# For volatile acidity
dataset["volatile acidity"].describe()
# Out:
# count    1351.000000
# mean        0.529726
# std         0.183053
# min         0.120000
# 25%         0.390000
# 50%         0.520000
# 75%         0.640000
# max         1.580000
# Name: volatile acidity, dtype: float64

# %%
#For citric acid
dataset["citric acid"].describe()
# Out:
# count    1351.000000
# mean        0.272287
# std         0.195544
# min         0.000000
# 25%         0.090000
# 50%         0.260000
# 75%         0.430000
# max         1.000000
# Name: citric acid, dtype: float64

# %%
# For residual sugar
dataset["residual sugar"].describe()
# Out:
# count    1351.000000
# mean        2.523686
# std         1.355158
# min         0.900000
# 25%         1.900000
# 50%         2.200000
# 75%         2.600000
# max        15.500000
# Name: residual sugar, dtype: float64

# %%
# For chlorides
dataset["chlorides"].describe()
# Out:
# count    1351.000000
# mean        0.088072
# std         0.049453
# min         0.012000
# 25%         0.070000
# 50%         0.079000
# 75%         0.090500
# max         0.611000
# Name: chlorides, dtype: float64

# %%
# For free sulfur dioxide
dataset["free sulfur dioxide"].describe()
# Out:
# count    1351.000000
# mean       15.869726
# std        10.418682
# min         1.000000
# 25%         7.000000
# 50%        14.000000
# 75%        21.000000
# max        72.000000
# Name: free sulfur dioxide, dtype: float64

# %%
# For total sulphur dioxide
dataset["total sulfur dioxide"].describe()
# Out:
# count    1351.000000
# mean       46.716136
# std        33.311742
# min         6.000000
# 25%        22.000000
# 50%        38.000000
# 75%        63.000000
# max       289.000000
# Name: total sulfur dioxide, dtype: float64

# %%
# For density
dataset["density"].describe()
# Out:
# count    1351.000000
# mean        0.996705
# std         0.001872
# min         0.990070
# 25%         0.995600
# 50%         0.996700
# 75%         0.997810
# max         1.003690
# Name: density, dtype: float64

# %%
# For pH
dataset["pH"].describe()
# Out:
# count    1351.000000
# mean        3.310148
# std         0.155191
# min         2.740000
# 25%         3.210000
# 50%         3.310000
# 75%         3.400000
# max         4.010000
# Name: pH, dtype: float64

# %%
# For sulphates
dataset["sulphates"].describe()
# Out:
# count    1351.000000
# mean        0.658727
# std         0.170763
# min         0.330000
# 25%         0.550000
# 50%         0.620000
# 75%         0.730000
# max         2.000000
# Name: sulphates, dtype: float64

# %%
# For alcohol
dataset["alcohol"].describe()
# Out:
# count    1351.000000
# mean       10.437984
# std         1.082632
# min         8.400000
# 25%         9.500000
# 50%        10.200000
# 75%        11.100000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
# For quality
dataset["quality"].describe()
# Out:
# count    1351.000000
# mean        5.624722
# std         0.824951
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %% [markdown]
# ## Statistical analysis of entire data

# %%
dataset.plot(kind="area",color=["red","yellow","green","blue","pink","black","grey","violet","cyan","brown","white","purple"])
plt.title("Plot Of Entire Data")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# -  From the graph above,the plot of the entire data shows that;
# -  the pH,alcohol and quality have the hihest count average between 50 and 350
# -  this is followed by the sulphates,free sulfur oxide,total sulfur dioxode,residual sugar and density all  of an average between approximately 20 and 50
# -  the least are the chlorides,fixed acidity,citric acid,volatile acidity of an count average approximately between 0 and 20

# %% [markdown]
# ### Accessing each column separately
# - Making a pie chat for each column

# %%
fig = plt.figure(figsize=(10,14), dpi=160)
explode = [0,0.1]
lb= ['Below', 'Above']

# For fixed acidity
x= dataset['fixed acidity'] < dataset['fixed acidity'].mean()
ax1 = plt.subplot2grid((4,3),(0,0))
plt.pie(x.value_counts(), colors=("y","g"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('fixed_acidity')

# For volatile acidity
y= dataset['volatile acidity'] < dataset['volatile acidity'].mean()
ax2 = plt.subplot2grid((4,3),(0, 1))
plt.pie(y.value_counts(),colors=("y","g"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('volatile_acidity')

# For citric acid
z = dataset['citric acid'] < dataset['citric acid'].mean()
ax3 = plt.subplot2grid((4,3),(0, 2))
plt.pie(z.value_counts(),colors=("y","g"),labels= lb, autopct = '%.2f%%', explode= explode)
plt.title('citric_acid')

#For residual sugar
a= dataset['residual sugar'] < dataset['residual sugar'].mean()
ax1 = plt.subplot2grid((4,3),(1,0))
plt.pie(a.value_counts(),colors=("y","g"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('residual_sugar')

# For chlorides
c=dataset.chlorides<dataset.chlorides.mean()
ax1 = plt.subplot2grid((4,3), (1, 1))
plt.pie(c.value_counts() ,colors=("y","g"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('chlorides')

#For sulphur dioxide
d= dataset['free sulfur dioxide']<dataset['free sulfur dioxide'].mean()
ax1 = plt.subplot2grid((4,3),(1,2))
plt.pie(d.value_counts() ,colors=("y","g"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('free_sulfur_dioxide')

# For total sulphur dioxide
e= dataset['total sulfur dioxide']< dataset['total sulfur dioxide'].mean()
ax1 = plt.subplot2grid((4,3),(2, 0))
plt.pie(e.value_counts(),colors=("y","g"),autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('total_sulfur_dioxide')

#For density
f= dataset.density < dataset.density.mean()
ax1 = plt.subplot2grid((4,3),(2, 1))
plt.pie(f.value_counts(),colors=("y","g"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('density')

#For pH
g= dataset.pH<dataset.pH.mean()
ax1 = plt.subplot2grid((4,3),(2,2))
plt.pie(g.value_counts(),colors=("y","g"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('pH')

#For sulphates
h=dataset.sulphates<dataset.sulphates.mean()
ax1 = plt.subplot2grid((4,3),(3,0))
plt.pie(h.value_counts(), colors=("y","g"),autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('sulphates')

# For alcohol
i=dataset.alcohol<dataset.alcohol.mean()
ax1 = plt.subplot2grid((4,3),(3,1))
plt.pie(i.value_counts(),colors=("y","g"), autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('alcohol')

#For quantity
j=dataset.quality<dataset.quality.mean()
ax1 = plt.subplot2grid((4,3),(3,2))
plt.pie(j.value_counts(),colors=("y","g"),autopct = '%.2f%%',explode= explode,labels= lb)
plt.title('quality')
# Out:
# Text(0.5, 1.0, 'quality')

# %% [markdown]
# - From the pie charts, it can be observed that
# - Residual sugar has the highest number of element concentration below the its mean (72.80%)
# - This followed by the chlorides (70.17%)
# - Follwed by the total sulphur dioxide (61.04%)
# - Follwed by the fixed acidity (60.60%)
# - Follwed by the sulphates (60.29%)
# - Follwed by the free sulphur dioxide (57.79%)
# - Follwed by the alchhol (57.29%)
# - Follwed by the quantity (53.47%)
# - Follwed by the citric acid (46.72%)
# - Follwed by the pH (48.59%)
# - Follwed by the volatile acidity (51.03%)
# - And lastly the density (50.9%)

# %% [markdown]
# ### Box plot of each column

# %%
plt.figure(figsize=(10,15))
for i, col in enumerate(list(dataset.columns.values)):
    plt.subplot(4,3,i+1)
    dataset.boxplot(col)
    plt.grid()
    plt.tight_layout()

# %% [markdown]
# - The points outside the 1.5-IQR range or more above the third quartile are considered outliers.
# - All other features have outliers besides alcohol.
